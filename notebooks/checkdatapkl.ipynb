# %%
import pickle
import os

# 定义文件路径
file_path = '/media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/maize1404/SNP_pca/1404cubic.pkl'
# /media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/maize1404/SNP_pca/1404cubic.pkl
# /media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/wheat599/SNP_origin/wheat599_X.pkl
# /media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/maize1404/392ind/SNP_pca/392_exp_snp_pc95.pkl
# /media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/maize1404/SNP_pca/1404cubic.pkl
# /media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/maize1404/392ind/exp/maize_exp.pkl
# /media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/maize1404/maize1404-F1/SNP_pca/cubicf1_pc95.pkl
# /media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/tomato332/SV_pca/332ind_SV_pc95.pkl
# /media/marxin/softs/workspace/Whisper_of_DNA_pl/data/example-data/wheat2000/SNP_origin/2000gene.pkl

try:
    # 检查文件是否存在
    if not os.path.exists(file_path):
        print(f"错误：文件未找到 - {file_path}")
    else:
        # 以二进制读取模式打开文件
        with open(file_path, 'rb') as f:
            # 加载 pickle 文件中的数据
            data = pickle.load(f)
            print("成功加载 pickle 文件！")
            # 你可以在这里处理加载的数据 'data'
            # 例如，打印数据类型或数据本身（如果数据量不大）
            print(f"数据类型: {type(data)}")
            # print("数据内容:")
            # print(data) # 取消注释以打印数据，但请注意数据可能很大

except FileNotFoundError:
    print(f"错误：文件未找到 - {file_path}")
except pickle.UnpicklingError:
    print(f"错误：无法反序列化文件 - {file_path}。文件可能已损坏或不是有效的 pickle 文件。")
except Exception as e:
    print(f"发生未知错误：{e}")
# Out:
# 成功加载 pickle 文件！
# 数据类型: <class 'pandas.core.frame.DataFrame'>
